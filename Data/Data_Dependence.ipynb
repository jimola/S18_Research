# %%
source('PTrees.R')
source('Datasets.R')
source('PTrees_General.R')

# %%
DTs <- dtree_outer(ttt, 5, 5, alg_5)

# %%
DTs
# Out:
# [[1]]
#                 levelName
# 1  ;V3
# 2   ¦--b;V2
# 3   ¦   ¦--b;V6
# 4   ¦   ¦   ¦--b;positive
# 5   ¦   ¦   ¦--o;positive
# 6   ¦   ¦   °--x;positive
# 7   ¦   ¦--o;V6
# 8   ¦   ¦   ¦--b;positive
# 9   ¦   ¦   ¦--o;positive
# 10  ¦   ¦   °--x;positive
# 11  ¦   °--x;V7
# 12  ¦       ¦--b;positive
# 13  ¦       ¦--o;positive
# 14  ¦       °--x;positive
# 15  ¦--o;V7
# 16  ¦   ¦--b;V5
# 17  ¦   ¦   ¦--b;negative
# 18  ¦   ¦   ¦--o;negative
# 19  ¦   ¦   °--x;positive
# 20  ¦   ¦--o;V5
# 21  ¦   ¦   ¦--b;negative
# 22  ¦   ¦   ¦--o;negative
# 23  ¦   ¦   °--x;positive
# 24  ¦   °--x;V1
# 25  ¦       ¦--b;positive
# 26  ¦       ¦--o;negative
# 27  ¦       °--x;positive
# 28  °--x;V1
# 29      ¦--b;V6
# 30      ¦   ¦--b;positive
# 31      ¦   ¦--o;positive
# 32      ¦   °--x;positive
# 33      ¦--o;V2
# 34      ¦   ¦--b;positive
# 35      ¦   ¦--o;positive
# 36      ¦   °--x;negative
# 37      °--x;V5
# 38          ¦--b;positive
# 39          ¦--o;positive
# ...

# %%
p <- predict_maj(DTs, ttt)
num_matching(ttt, p)
# Out:
# [1] 0.743215
